# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y, color='green',marker='*',linestyle='dotted',markersize=20,alpha=0.5)#alpha for transparency

# %%
plt.plot(x,y,'r+--')
